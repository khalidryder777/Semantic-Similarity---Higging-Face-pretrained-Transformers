# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ego_text.csv', encoding='cp1252')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          193 non-null    int64
#  1   ES_ellab    193 non-null    object
#  2   ES_distill  193 non-null    object
#  3   EP_ellab    193 non-null    object
#  4   EP_distill  193 non-null    object
#  5   AS_ellab    193 non-null    object
#  6   AS_distill  193 non-null    object
#  7   AP_ellab    193 non-null    object
#  8   AP_distill  193 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 13.7+ KB

# %%
for i in range(len(df)):
    sentences = []
    sentences.append(df.iloc[:,1][i])
    sentences.append(df.iloc[:,2][i])
    print(sentences)
# Out:
# ['I imagine, that I was friend with Ariel. I imagine we were going to get food. It can also be that we were walking to class together or commuting together.', 'what instances I would find myself walking with Ariel']
# ['I am eating with Sam. We are eating pancake at the dinner table. The sun is bright. It is a brunch.', 'We are eating brunch']
# ["I picture the journey to Sam's house on a sunny day in New York. I picture all of the different people I pass in their own worlds, and the cute apartments and shops I look into as I walk by. I imagine myself making it to his house and it being warm out from the sun so we hang out in the backyard of his brownstone on a hammock.", 'I visited my friend on a warm NY day.']
# ['I talk about the exam. Sam told me that I got the last multiple choice wrong. I am really pissed because I thought I got it right. I ask Sam to help me with the exam happening next Monday.', 'I talk about the exam with Sam.']
# ...

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd






#from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/paraphrase-MiniLM-L6-v2')
#sentences = ["This is an example sentence", "Each sentence is converted"]

#df = pd.read_csv('C:\Users\khali\Pictures\ego_text.csv', encoding='mac-roman')

# model = SentenceTransformer('sentence-transformers/paraphrase-MiniLM-L6-v2')


# embeddings = model.encode(sentences)
# #print(embeddings.shape) #embeddings[[0],[1]]
# #print(embeddings)




# score = cosine_similarity(embeddings[[0]],embeddings[[1]])#[0]
# print(score)

# #print(embeddings.shape)

x = []

for i in range(len(df)):
    sentences = []
    sentences.append(df.iloc[:,1][i])
    sentences.append(df.iloc[:,2][i])
    #print(sentences)
    


    embeddings = model.encode(sentences)
#     print(embeddings.shape) #embeddings[[0],[1]]
#     print(embeddings)




    score = cosine_similarity(embeddings[[0]],embeddings[[1]])#[0]
    #print(score)
    s = score.tolist()       
    x.append(s[0][0])  
    
print(x)
# Out:
# [0.6265663504600525, 0.6795867681503296, 0.42878445982933044, 0.7012587785720825, 0.8634714484214783, 0.7131488919258118, 0.8111387491226196, 0.7420682907104492, 0.5549196600914001, 0.7823361158370972, 0.6251881122589111, 0.36253172159194946, 0.8584794998168945, 0.8345273733139038, 0.5492569208145142, 0.6049720048904419, 0.2583969831466675, 0.6552153825759888, 0.6075631380081177, 0.668306827545166, 0.6575700640678406, 0.6586277484893799, 0.6783316731452942, 0.9999998807907104, 0.4472962021827698, 0.3142626881599426, 0.4508076310157776, 0.6165101528167725, 0.7859983444213867, 0.7171655893325806, 0.6922756433486938, 0.3691555857658386, 0.5853919982910156, 0.8292011022567749, 0.4246666133403778, 0.7058646082878113, 0.36187273263931274, 0.6932867169380188, 0.3166620433330536, 0.7518082857131958, 0.8152276277542114, 0.6807183027267456, 0.2788415551185608, 0.45406728982925415, 0.786249041557312, 0.5611163377761841, 0.6936749219894409, 0.6625864505767822, 0.7656960487365723, 0.6663377881050
# ...

# %%
len(x)
ES_sim1 = x

print(ES_sim1)
# Out:
# [0.6265663504600525, 0.6795867681503296, 0.42878445982933044, 0.7012587785720825, 0.8634714484214783, 0.7131488919258118, 0.8111387491226196, 0.7420682907104492, 0.5549196600914001, 0.7823361158370972, 0.6251881122589111, 0.36253172159194946, 0.8584794998168945, 0.8345273733139038, 0.5492569208145142, 0.6049720048904419, 0.2583969831466675, 0.6552153825759888, 0.6075631380081177, 0.668306827545166, 0.6575700640678406, 0.6586277484893799, 0.6783316731452942, 0.9999998807907104, 0.4472962021827698, 0.3142626881599426, 0.4508076310157776, 0.6165101528167725, 0.7859983444213867, 0.7171655893325806, 0.6922756433486938, 0.3691555857658386, 0.5853919982910156, 0.8292011022567749, 0.4246666133403778, 0.7058646082878113, 0.36187273263931274, 0.6932867169380188, 0.3166620433330536, 0.7518082857131958, 0.8152276277542114, 0.6807183027267456, 0.2788415551185608, 0.45406728982925415, 0.786249041557312, 0.5611163377761841, 0.6936749219894409, 0.6625864505767822, 0.7656960487365723, 0.6663377881050
# ...

# %%
y = []

model = SentenceTransformer('sentence-transformers/paraphrase-MiniLM-L6-v2')
for i in range(len(df)):
    sentences = []
    sentences.append(df.iloc[:,3][i])
    sentences.append(df.iloc[:,4][i])
    #print(sentences)
    


    embeddings = model.encode(sentences)
#     print(embeddings.shape) #embeddings[[0],[1]]
#     print(embeddings)




    score = cosine_similarity(embeddings[[0]],embeddings[[1]])#[0]
    #print(score)
    s = score.tolist()       
    y.append(s[0][0])  
    
print(y)
# Out:
# [0.48398101329803467, 0.6670844554901123, 0.5754492282867432, 0.6271328330039978, 0.8326566219329834, 0.4468768537044525, 0.752787709236145, 0.4415516257286072, 0.3366765081882477, 0.8308376669883728, 0.3708592355251312, 0.6413887739181519, 0.8320178389549255, 0.8582906723022461, 0.6307286024093628, 0.7422462701797485, 0.028883785009384155, 0.675870954990387, 0.6997233629226685, 0.7746307253837585, 0.48021578788757324, 0.6560003161430359, 0.4414898157119751, 1.0, 0.49305757880210876, 0.4972432255744934, 0.580779492855072, 0.6302957534790039, 0.6632055044174194, 0.723576545715332, 0.4693012237548828, 0.6393346190452576, 0.6620463132858276, 0.38847845792770386, 0.4059005379676819, 0.6396894454956055, 0.2595827579498291, 0.8667344450950623, 0.8291436433792114, 0.23284970223903656, 0.5766434669494629, 0.5899704098701477, 0.5386894941329956, 0.5629033446311951, 0.7330989241600037, 0.4438236355781555, 0.6416895985603333, 0.5261433124542236, 0.8750008940696716, 0.7881553769111633, 0.5848033
# ...

# %%
EP_sim1 = y

print(EP_sim1)
# Out:
# ...

# %%
a = []

model = SentenceTransformer('sentence-transformers/paraphrase-MiniLM-L6-v2')
for i in range(len(df)):
    sentences = []
    sentences.append(df.iloc[:,7][i])
    sentences.append(df.iloc[:,8][i])
    #print(sentences)
    


    embeddings = model.encode(sentences)
#     print(embeddings.shape) #embeddings[[0],[1]]
#     print(embeddings)




    score = cosine_similarity(embeddings[[0]],embeddings[[1]])#[0]
    #print(score)
    s = score.tolist()       
    a.append(s[0][0])  
    
print(a)
# Out:
# [0.4519627094268799, 0.2754412293434143, 0.7698692083358765, 0.7027769088745117, 0.7446640729904175, 0.5205024480819702, 0.7415735721588135, 0.7598118782043457, 0.6174225211143494, 0.8019561767578125, 0.49826380610466003, 0.2732661962509155, 0.9023889303207397, 0.8173849582672119, 0.8046216368675232, 0.46590855717658997, 0.3653084337711334, 0.7430761456489563, 0.49546170234680176, 0.7688304781913757, 0.7324826121330261, 0.31070879101753235, 0.7599208354949951, 0.8516240119934082, 0.1137564405798912, 0.2752380967140198, 0.7309428453445435, 0.7384777069091797, 0.6167148947715759, 0.3020065724849701, 0.6783520579338074, 0.3817151188850403, 0.5084771513938904, 0.5424641370773315, 0.4494219720363617, 0.8286809921264648, 0.16266264021396637, 0.7959592342376709, 0.43211185932159424, 0.3571912348270416, 0.6002353429794312, 0.6957027912139893, 0.26770880818367004, 0.7918221950531006, 0.845534086227417, 0.5779569149017334, 0.6151787042617798, 0.7495235204696655, 0.9231228828430176, 0.734616041
# ...

# %%
AP_sim1 = a

print(AP_sim1)
# Out:
# [0.4519627094268799, 0.2754412293434143, 0.7698692083358765, 0.7027769088745117, 0.7446640729904175, 0.5205024480819702, 0.7415735721588135, 0.7598118782043457, 0.6174225211143494, 0.8019561767578125, 0.49826380610466003, 0.2732661962509155, 0.9023889303207397, 0.8173849582672119, 0.8046216368675232, 0.46590855717658997, 0.3653084337711334, 0.7430761456489563, 0.49546170234680176, 0.7688304781913757, 0.7324826121330261, 0.31070879101753235, 0.7599208354949951, 0.8516240119934082, 0.1137564405798912, 0.2752380967140198, 0.7309428453445435, 0.7384777069091797, 0.6167148947715759, 0.3020065724849701, 0.6783520579338074, 0.3817151188850403, 0.5084771513938904, 0.5424641370773315, 0.4494219720363617, 0.8286809921264648, 0.16266264021396637, 0.7959592342376709, 0.43211185932159424, 0.3571912348270416, 0.6002353429794312, 0.6957027912139893, 0.26770880818367004, 0.7918221950531006, 0.845534086227417, 0.5779569149017334, 0.6151787042617798, 0.7495235204696655, 0.9231228828430176, 0.734616041
# ...

# %%
#data1 = pd.DataFrame(data=[ES_sim1, EP_sim1, AS_sim1, AP_sim1])
data1 = pd.DataFrame(list(zip(ES_sim1, EP_sim1, AS_sim1, AP_sim1)),
# %%
len(AP_sim1)
# Out:
# 190

# %%
 #data1 = pd.DataFrame(data=[ES_sim1, EP_sim1, AS_sim1, AP_sim1])
df_tst = pd.DataFrame(list(zip(ES_sim1, EP_sim1, AS_sim1, AP_sim1)),
               columns =['ES_sim1', 'EP_sim1', 'AS_sim1', 'AP_sim1'])

# %%
df_tst
# Out:
#       ES_sim1   EP_sim1   AS_sim1   AP_sim1
# 0    0.626566  0.483981  0.852075  0.451963
# 1    0.679587  0.667084  0.677201  0.275441
# 2    0.428784  0.575449  0.575516  0.769869
# 3    0.701259  0.627133  0.702050  0.702777
# 4    0.863471  0.832657  0.833127  0.744664
# ..        ...       ...       ...       ...
# 185  0.799986  0.782263  0.729648  0.772840
# 186  0.617004  0.685724  0.752414  0.558958
# 187  0.683326  0.575547  0.566778  0.726567
# 188  0.642029  0.517995  0.787953  0.543503
# 189  0.692777  0.658962  0.864745  0.890415
#
# [190 rows x 4 columns]

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd






from sentence_transformers import SentenceTransformer

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

#sentences = ["This is an example sentence", "Each sentence is converted"]

#df = pd.read_csv('C:\Users\khali\Pictures\ego_text.csv', encoding='mac-roman')

# model = SentenceTransformer('sentence-transformers/paraphrase-MiniLM-L6-v2')


# embeddings = model.encode(sentences)
# #print(embeddings.shape) #embeddings[[0],[1]]
# #print(embeddings)




# score = cosine_similarity(embeddings[[0]],embeddings[[1]])#[0]
# print(score)

# #print(embeddings.shape)

b = []

for i in range(len(df)):
    sentences = []
    sentences.append(df.iloc[:,1][i])
    sentences.append(df.iloc[:,2][i])
    #print(sentences)
    

    embeddings = model.encode(sentences)
#     print(embeddings.shape) #embeddings[[0],[1]]
#     print(embeddings)




    score = cosine_similarity(embeddings[[0]],embeddings[[1]])#[0]
    #print(score)
    s = score.tolist()       
    b.append(s[0][0])  
    
print(b)
# Out:
# [0.5486536026000977, 0.5163501501083374, 0.49030742049217224, 0.657336413860321, 0.9132095575332642, 0.7266440391540527, 0.8243194818496704, 0.8160860538482666, 0.5961394309997559, 0.7654644846916199, 0.6570948958396912, 0.38636869192123413, 0.890069842338562, 0.8430098295211792, 0.6464254856109619, 0.5927251577377319, 0.1955374777317047, 0.7006343603134155, 0.5921511650085449, 0.6867738962173462, 0.6949136257171631, 0.7405406832695007, 0.735919713973999, 1.000000238418579, 0.4116729497909546, 0.37713348865509033, 0.28871455788612366, 0.618317723274231, 0.7994027137756348, 0.7824707627296448, 0.5409451723098755, 0.3278604745864868, 0.5950616598129272, 0.7821704149246216, 0.41109389066696167, 0.8096657991409302, 0.424450546503067, 0.7434200644493103, 0.34431058168411255, 0.7812626957893372, 0.8311372399330139, 0.7606232166290283, 0.33831682801246643, 0.6928137540817261, 0.8649260997772217, 0.5004114508628845, 0.6961032152175903, 0.7361838817596436, 0.7053524851799011, 0.68711662292480
# ...

# %%
ES_sim2 = b

# %%
c = []

for i in range(len(df)):
    sentences = []
    sentences.append(df.iloc[:,3][i])
    sentences.append(df.iloc[:,4][i])
    #print(sentences)
    

    embeddings = model.encode(sentences)
#     print(embeddings.shape) #embeddings[[0],[1]]
#     print(embeddings)




    score = cosine_similarity(embeddings[[0]],embeddings[[1]])#[0]
    #print(score)
    s = score.tolist()       
    c.append(s[0][0])  
    
print(c)
# Out:
# [0.5402295589447021, 0.562515139579773, 0.550262451171875, 0.5636762976646423, 0.7611123323440552, 0.423423171043396, 0.8793157935142517, 0.48184341192245483, 0.39623570442199707, 0.8681087493896484, 0.34921014308929443, 0.747520923614502, 0.8813207149505615, 0.8634409308433533, 0.66807621717453, 0.7278016805648804, 0.10319754481315613, 0.6563757658004761, 0.6363242864608765, 0.860704779624939, 0.40052491426467896, 0.6575843095779419, 0.3011726438999176, 1.0, 0.4624471068382263, 0.46150314807891846, 0.6059203147888184, 0.7489598393440247, 0.8021095395088196, 0.7975317239761353, 0.4022362232208252, 0.5884097218513489, 0.7212139964103699, 0.404660165309906, 0.49945905804634094, 0.6769344210624695, 0.2798471748828888, 0.8592619895935059, 0.7531465291976929, 0.37223583459854126, 0.7386646270751953, 0.5399514436721802, 0.5380378365516663, 0.6156625747680664, 0.7257944941520691, 0.4868205189704895, 0.5654115080833435, 0.6247076392173767, 0.8827533721923828, 0.8669684529304504, 0.5535336732
# ...

# %%
EP_sim2 = c

# %%
d = []

for i in range(len(df)):
    sentences = []
    sentences.append(df.iloc[:,5][i])
    sentences.append(df.iloc[:,6][i])
    #print(sentences)
    

    embeddings = model.encode(sentences)
#     print(embeddings.shape) #embeddings[[0],[1]]
#     print(embeddings)




    score = cosine_similarity(embeddings[[0]],embeddings[[1]])#[0]
    #print(score)
    s = score.tolist()       
    d.append(s[0][0])  
    
print(d)
# Out:
# [0.8493572473526001, 0.7250989675521851, 0.6630972623825073, 0.7014458179473877, 0.8410946130752563, 0.6396918296813965, 0.8301884531974792, 0.7877493500709534, 0.31343305110931396, 0.5588395595550537, 0.7847493886947632, 0.6901794075965881, 0.8311710357666016, 0.8285977244377136, 0.7635390162467957, 0.5337238311767578, 0.34769806265830994, 0.8405726552009583, 0.7201778888702393, 0.835584282875061, 0.6311919689178467, 0.5096735954284668, 0.7558091878890991, 0.41997429728507996, 0.2559742331504822, 0.4538458585739136, 0.4703312814235687, 0.7313536405563354, 0.7130609750747681, 0.8300060033798218, 0.8821188807487488, 0.34095683693885803, 0.7823126316070557, 0.7118508219718933, 0.7942209243774414, 0.6961702108383179, 0.3495473265647888, 0.9142725467681885, 0.4083867073059082, 0.885390043258667, 0.6115438342094421, 0.5622153282165527, 0.29338693618774414, 0.7146772146224976, 0.7387442588806152, 0.779134213924408, 0.7946344614028931, 0.7603504657745361, 0.8663562536239624, 0.8757808804512
# ...

# %%
AS_sim2 = d

# %%
e = []

for i in range(len(df)):
    sentences = []
    sentences.append(df.iloc[:,7][i])
    sentences.append(df.iloc[:,8][i])
    #print(sentences)
    

    embeddings = model.encode(sentences)
#     print(embeddings.shape) #embeddings[[0],[1]]
#     print(embeddings)




    score = cosine_similarity(embeddings[[0]],embeddings[[1]])#[0]
    #print(score)
    s = score.tolist()       
    e.append(s[0][0])  
    
print(e)
# Out:
# [0.3308362662792206, 0.18922021985054016, 0.7531973123550415, 0.7457446455955505, 0.7392638325691223, 0.4283132255077362, 0.7594179511070251, 0.7954736948013306, 0.6441881060600281, 0.7569583654403687, 0.501305103302002, 0.3487168550491333, 0.9268631935119629, 0.9198018908500671, 0.8240296840667725, 0.6350740194320679, 0.47440189123153687, 0.7882636785507202, 0.3528596758842468, 0.7726432085037231, 0.6358941793441772, 0.24538269639015198, 0.702406644821167, 0.8254387974739075, 0.19858112931251526, 0.25980401039123535, 0.7573117017745972, 0.8472170829772949, 0.6538980007171631, 0.4161975085735321, 0.6920359134674072, 0.28475427627563477, 0.4764000177383423, 0.505824089050293, 0.41668465733528137, 0.8515002131462097, 0.21621975302696228, 0.8501467108726501, 0.4804649353027344, 0.4331595301628113, 0.5657045245170593, 0.6450926065444946, 0.2770203649997711, 0.7375562191009521, 0.9071829915046692, 0.5911540985107422, 0.6045036911964417, 0.7677257061004639, 0.9659945964813232, 0.7975974678
# ...

# %%
AP_sim2 = e

# %%
OP_data = pd.DataFrame(list(zip(ES_sim1, EP_sim1, AS_sim1, AP_sim1, ES_sim2, EP_sim2, AS_sim2, AP_sim2)),
               columns =['ES_sim1', 'EP_sim1', 'AS_sim1', 'AP_sim1', 'ES_sim2', 'EP_sim2', 'AS_sim2', 'AP_sim2'])

# %%
OP_data
# Out:
#       ES_sim1   EP_sim1   AS_sim1   AP_sim1   ES_sim2   EP_sim2   AS_sim2  \
# 0    0.626566  0.483981  0.852075  0.451963  0.548654  0.540230  0.849357
# 1    0.679587  0.667084  0.677201  0.275441  0.516350  0.562515  0.725099
# 2    0.428784  0.575449  0.575516  0.769869  0.490307  0.550262  0.663097
# 3    0.701259  0.627133  0.702050  0.702777  0.657336  0.563676  0.701446
# 4    0.863471  0.832657  0.833127  0.744664  0.913210  0.761112  0.841095
# ..        ...       ...       ...       ...       ...       ...       ...
# 188  0.799986  0.782263  0.729648  0.772840  0.841143  0.803144  0.861378
# 189  0.617004  0.685724  0.752414  0.558958  0.706848  0.788426  0.759866
# 190  0.683326  0.575547  0.566778  0.726567  0.842404  0.628820  0.651081
# 191  0.642029  0.517995  0.787953  0.543503  0.743163  0.638384  0.641149
# 192  0.692777  0.658962  0.864745  0.890415  0.672913  0.635943  0.900926
#
#       AP_sim2
# 0    0.330836
# 1    0.189220
# 2    0.753197
# 3    0.745745
# ...

# %%
result = pd.concat([df, OP_data], axis=1)

# %%
result.head()
# Out:
#    ID                                           ES_ellab  \
# 0   1  I imagine, that I was friend with Ariel. I ima...
# 1   2  I am eating with Sam. We are eating pancake at...
# 2   3  I picture the journey to Sam's house on a sunn...
# 3   4  I talk about the exam. Sam told me that I got ...
# 4   5  I ate pizza with Sam. Sam had a salad. We talk...
#
#                                           ES_distill  \
# 0  what instances I would find myself walking wit...
# 1                               We are eating brunch
# 2              I visited my friend on a warm NY day.
# 3                    I talk about the exam with Sam.
# 4  Sam and I ate food while we talked about his b...
#
#                                             EP_ellab  \
# 0  I visited Sam and Jessie between classes at th...
# 1  I am walking with Ariel and Taylor. I am in th...
# 2  We are walking down a sunny street with iced c...
# 3  I am having dinner with Jessie and Taylor. We ...
# ...

# %%
OP_data.to_csv('sim_only', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5144/400452409.py in <module>
#       1 OP_data.to_csv('sim_only', index=False)
# ----> 2 df1 = sim_only
#
# NameError: name 'sim_only' is not defined

# %%
df1 = pd.read_csv('sim_only')

df2 = pd.concat([df['ID'], df1], axis=1)

df1.to_csv('sim_only', index=False)

# %%
result.to_csv('df_sim', index=False)

# %%
pd.read_csv('df_sim').head()
# Out:
#    ID                                           ES_ellab  \
# 0   1  I imagine, that I was friend with Ariel. I ima...
# 1   2  I am eating with Sam. We are eating pancake at...
# 2   3  I picture the journey to Sam's house on a sunn...
# 3   4  I talk about the exam. Sam told me that I got ...
# 4   5  I ate pizza with Sam. Sam had a salad. We talk...
#
#                                           ES_distill  \
# 0  what instances I would find myself walking wit...
# 1                               We are eating brunch
# 2              I visited my friend on a warm NY day.
# 3                    I talk about the exam with Sam.
# 4  Sam and I ate food while we talked about his b...
#
#                                             EP_ellab  \
# 0  I visited Sam and Jessie between classes at th...
# 1  I am walking with Ariel and Taylor. I am in th...
# 2  We are walking down a sunny street with iced c...
# 3  I am having dinner with Jessie and Taylor. We ...
# ...

# %%
OP_data.to_excel('sim_only.xlsx', sheet_name='sim_only')
result.to_excel('df_sim.xlsx', sheet_name='df_sim')

# %%
df2.to_excel('Sim_Only.xlsx', sheet_name='Sim_Only')

# %%
df2.to_csv('Sim_Only', index=False)

# %%
pd.read_csv('Sim_Only')
# Out:
#       ID   ES_sim1   EP_sim1   AS_sim1   AP_sim1   ES_sim2   EP_sim2  \
# 0      1  0.626566  0.483981  0.852075  0.451963  0.548654  0.540230
# 1      2  0.679587  0.667084  0.677201  0.275441  0.516350  0.562515
# 2      3  0.428784  0.575449  0.575516  0.769869  0.490307  0.550262
# 3      4  0.701259  0.627133  0.702050  0.702777  0.657336  0.563676
# 4      5  0.863471  0.832657  0.833127  0.744664  0.913210  0.761112
# ..   ...       ...       ...       ...       ...       ...       ...
# 188  189  0.799986  0.782263  0.729648  0.772840  0.841143  0.803144
# 189  190  0.617004  0.685724  0.752414  0.558958  0.706848  0.788426
# 190  191  0.683326  0.575547  0.566778  0.726567  0.842404  0.628820
# 191  192  0.642029  0.517995  0.787953  0.543503  0.743163  0.638384
# 192  193  0.692777  0.658962  0.864745  0.890415  0.672913  0.635943
#
#       AS_sim2   AP_sim2
# 0    0.849357  0.330836
# 1    0.725099  0.189220
# 2    0.663097  0.753197
# 3    0.701446  0.745745
# ...
